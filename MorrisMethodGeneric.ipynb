# %% [markdown]
# # Morris Method for Habitability Zone
# Unlike the previous example, this time I'm recursing through all the objects in the dataset to see if it's habitable

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
df = pd.read_csv("Exoplanets.csv")
print(df.columns)
# Out:
# Index(['rowid', 'pl_hostname', 'pl_letter', 'pl_name', 'pl_discmethod',
#        'pl_pnum', 'pl_orbper', 'pl_orbpererr1', 'pl_orbpererr2',
#        'pl_orbperlim',
#        ...
#        'st_bmy', 'st_bmyerr', 'st_bmylim', 'st_m1', 'st_m1err', 'st_m1lim',
#        'st_c1', 'st_c1err', 'st_c1lim', 'st_colorn'],
#       dtype='object', length=355)

# %%
df = df[df['st_optmag'].notna()]
df = df[df['st_spstr'].notna()]

habitablePlanets = []
# This list stores indexes of all the habitable exoplanets
for index, row in df.iterrows():
    opticalMagnitude = df['st_optmag']
    distanceInParsecs = df['st_dist']
    #absoluteMagnitude = opticalMagnitude - (5 * math.log10(distanceInParsecs/10))
    print(df['st_spstr'])
# Out:
# 0       K0 III
# 1       K4 III
# 2       G8 III
# 3         K0 V
# 4       G2.5 V
#          ...
# 3833    K2 III
# 3834      F8 V
# 3835      F8 V
# 3836      F8 V
# 3837    G9 III
# Name: st_spstr, Length: 1134, dtype: object
# 0       K0 III
# 1       K4 III
# 2       G8 III
# 3         K0 V
# 4       G2.5 V
#          ...
# 3833    K2 III
# 3834      F8 V
# 3835      F8 V
# 3836      F8 V
# 3837    G9 III
# Name: st_spstr, Length: 1134, dtype: object
# 0       K0 III
# 1       K4 III
# 2       G8 III
# 3         K0 V
# 4       G2.5 V
#          ...
# 3833    K2 III
# 3834      F8 V
# 3835      F8 V
# 3836      F8 V
# 3837    G9 III
# Name: st_spstr, Length: 1134, dtype: object
# 0       K0 III
# 1       K4 III
# 2       G8 III
# 3         K0 V
# 4       G2.5 V
#          ...
# 3833    K2 III
# 3834      F8 V
# 3835      F8 V
# 3836      F8 V
# 3837    G9 III
# Name: st_spstr, Length: 1134, dtype: object
# 0       K0 III
# 1       K4 III
# 2       G8 III
# 3         K0 V
# ...
